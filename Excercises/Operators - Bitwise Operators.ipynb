# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
10 & 12 # the and(&) on binary representation of 10 (1010) and 12 (1100)
# Out:
# 8

# %%
10 | 12
# Out:
# 14

# %%
10 >> 2 # 10 is 1010; right shift gives 10 which is 2 in decimal
# Out:
# 2

# %%
10 << 2 # 10 is 1010; left shift gives 101000 which is 40 in decimal
# Out:
# 40
