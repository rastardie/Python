# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
list1 = [10, 20, 30]
list2 = [10, 20, 30]

# %%
x = list1

# %%
x is list1
# Out:
# True

# %%
list1 is list2
# Out:
# False

# %%
list1 is not list2
# Out:
# True
