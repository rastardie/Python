# %% [markdown]
# # Python Collections
# * Collections are container data types; Lists, Tuples, Sets, and    Dictionary
#
# * Python has a built in data type called Collections that combines the collections data types
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # namedtuple()
# * Returns a tuple with a named value for each element in the tuple

# %%
Details = (name = 'edureka', course='python', course2 = 'data science')
# Out:
#   File "<ipython-input-1-597e2ccd4241>", line 1
#     Details = (name = 'edureka', course='python', course2 = 'data science')
#                     ^
# SyntaxError: invalid syntax
