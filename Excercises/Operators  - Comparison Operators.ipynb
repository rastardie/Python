# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
val = 10 
num1 = 20

# %%
compare = val == num1

# %%
compare
# Out:
# False

# %%
compare = val == num1
compare
# Out:
# False

# %%
val = 10 
num1 = 20 
compare = val < num1
compare
# Out:
# True

# %%
val = 10 
num1 = 20 
compare = val != num1
compare
# Out:
# True

# %%
val = 10 
num1 = 20 
compare = val >= num1
compare
# Out:
# False
