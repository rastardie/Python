# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
#The conditinal operators in Python are: 
# if
# elif (else if) and 
# else
# The Logical Operators are 'and', 'not' and 'or'

# %%
val = 10 
num1 = 15

# %%
#conditional statements
if val == num1:
    print('equal')
elif val > num1:
    print('greater')
else:
    print('smaller')
# Out:
# smaller

# %%
x = 10

# %%
x > 10 and x > 5  #both conditions must the true for the output to be true
# Out:
# False

# %%
x > 10 and x > 5
# Out:
# True

# %%
#both conditions must the true for the output to be true  #one conditions must the true for the output to be true
# Out:
# True

# %%
x > 10 and x > 12
# Out:
# False

# %%
x > 8 and x > 5
# Out:
# True

# %%
not(x > 10 and x > 5)  # negating the output
# Out:
# True

# %%
not(x > 10 or x > 5)
# Out:
# False
