# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
x = 10 
y = 20

# %%
x + y
# Out:
# 30

# %%
x - y
# Out:
# -10

# %%
x * y
# Out:
# 200

# %%
x / y
# Out:
# 0.5

# %%
x ** y #x exponent y
# Out:
# 100000000000000000000

# %%
x // y # floor
# Out:
# 0

# %%
x % y #modulo
# Out:
# 10
