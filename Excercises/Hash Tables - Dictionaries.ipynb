# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
my_dict={'Dave': '001', 'Ava': '002', 'Joe': '003'} # method of creating a dictionalry (using curly brackets)
print(my_dict)
type(my_dict)
# Out:
# {'Dave': '001', 'Ava': '002', 'Joe': '003'}
# dict

# %%
new_dict=dict()        #Method of 2 of creating a dictionary (using the dict() function)
print(new_dict)
type(new_dict)
# Out:
# {}
# dict

# %%
new_dict=dict(Dave='001', Ava='002')
print(new_dict)
# Out:
# {'Dave': '001', 'Ava': '002'}
