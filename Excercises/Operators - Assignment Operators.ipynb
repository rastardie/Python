# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
a  # in python variables must be assigned befor it can be referenced
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8094deb9fe1d> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = 5

# %%
a += 5  # a = a + 5

# %%
a
# Out:
# 10

# %%
a **= 5 
a
# Out:
# 100000

# %%
a
# Out:
# 100000
