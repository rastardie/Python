# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
list1 = [10, 20, 30]
list2 = [10, 20, 30]
x = list1

# %%
x in list1
# Out:
# False

# %%
list1 in list2
# Out:
# False

# %%
10 in list1
# Out:
# True

# %%
list1 == list2
# Out:
# True

# %%
list1 = [10, 20, 30, 'banana']
list2 = [10, 20, 30]

# %%
list1 == list2
# Out:
# False
