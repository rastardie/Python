# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
emp_details={'Employee': {'Dave': {'ID': '001', 'Salary': '2000', 'Designation': 'Team Lead'}, 
                         'Ava':{'ID': '002', 'Salary': '2000', 'Designation': 'Associate'}}}
print(emp_details)
# Out:
# {'Employee': {'Dave': {'ID': '001', 'Salary': '2000', 'Designation': 'Team Lead'}, 'Ava': {'ID': '002', 'Salary': '2000', 'Designation': 'Associate'}}}
