# %% [markdown]
# # Type Conversion
# * Type conversion is used to convert a variable to another data type
# ![image.png](attachment:image.png)

# %%
x = 10

# %%
name = 'name'

# %%
x  + name  # Type error (can't int and str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cbea4f8646ec> in <module>
# ----> 1 x  + name  # Type error (can't int and str)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(x)+name # int converted to str
# Out:
# '10name'

# %%
b = {4, 5, 6}  # A dictionary

# %%
list(b)   # converted a dictionary into a list
# Out:
# [4, 5, 6]
